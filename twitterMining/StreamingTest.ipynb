# %%
from twython import TwythonStreamer

# %%
def getKeys(file_path):
    keys = []
    with open(file_path, 'r') as f:
        for line in f:
            keys.append(line.replace('\n', ''))
    return keys

APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET = getKeys('../../twitterKeys.txt')

# %%
class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            #print(data)
            #print(data['text'])
            append_to_file('hillaryTrumpNotHash.txt', data['text'] + '\n')

    def on_error(self, status_code, data):
        print(status_code)

        # Want to stop trying to get data because of the error?
        # Uncomment the next line!
        self.disconnect()

# %%
def append_to_file(path, data):
    """
    append_to_file appends a line of data to specified file.  Then adds new line
    
    Args:
        path (string): the file path
    
    Return:
        VOID
    """
    with open(path, 'a') as file:
        file.write(data + '\n')

# %%
def set_to_file(tweets, file_name):
    """
    set_to_file iterates through a set, each tweet is a new line in the file
    
    ARGS:
        links (set): a set that contains tweets
        file_name (string): the name of the file we want to write to
        
    Return:
        VOID
    """
    for tweet in tweets:
        append_to_file(file_name, tweet)

# %%
stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
stream.statuses.filter(track='hillary, trump')
#'#python, #java, #javascript, #haskell, #clojure'
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/response.py in _error_catcher(self)
#     225             try:
# --> 226                 yield
#     227
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     488                     break
# --> 489                 chunk = self._handle_chunk(amt)
#     490                 decoded = self._decode(chunk, decode_content=decode_content,
#
# /usr/lib/python3/dist-packages/urllib3/response.py in _handle_chunk(self, amt)
#     448         elif amt < self.chunk_left:
# --> 449             value = self._fp._safe_read(amt)
#     450             self.chunk_left = self.chunk_left - amt
#
# /usr/lib/python3.5/http/client.py in _safe_read(self, amt)
#     608             if not chunk:
# --> 609                 raise IncompleteRead(b''.join(s), amt)
#     610             s.append(chunk)
#
# IncompleteRead: IncompleteRead(0 bytes read, 1 more expected)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     659                 try:
# --> 660                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     661                         yield chunk
#
# /usr/lib/python3/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     339         if self.chunked:
# --> 340             for line in self.read_chunked(amt, decode_content=decode_content):
#     341                 yield line
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     513             if self._original_response:
# --> 514                 self._original_response.close()
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#
# /usr/lib/python3/dist-packages/urllib3/response.py in _error_catcher(self)
#     243                 # This includes IncompleteRead.
# --> 244                 raise ProtocolError('Connection broken: %r' % e, e)
#     245
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read, 1 more expected)', IncompleteRead(0 bytes read, 1 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-6-782375281f1d> in <module>()
#       1 stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# ----> 2 stream.statuses.filter(track='hillary, trump')
#       3 #'#python, #java, #javascript, #haskell, #clojure'
#
# /usr/lib/python3/dist-packages/twython/streaming/types.py in filter(self, **params)
#      64         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      65               % self.streamer.api_version
# ---> 66         self.streamer._request(url, 'POST', params=params)
#      67
#      68     def sample(self, **params):
#
# /usr/lib/python3/dist-packages/twython/streaming/api.py in _request(self, url, method, params)
#     139             response = _send(retry_counter)
#     140
# --> 141             for line in response.iter_lines(self.chunk_size):
#     142                 if not self.connected:
#     143                     break
#
# /usr/lib/python3/dist-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     700         pending = None
#     701
# --> 702         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     703
#     704             if pending is not None:
#
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     661                         yield chunk
#     662                 except ProtocolError as e:
# --> 663                     raise ChunkedEncodingError(e)
#     664                 except DecodeError as e:
#     665                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(0 bytes read, 1 more expected)', IncompleteRead(0 bytes read, 1 more expected))

# %%
def file_to_list(file_name):
    """
    file_to_set reads a file and converts each line to set items
    ii
    Args:
        file_name (string): the name of the file
        
    Returns:
        (list): the items that are in the file
    """
    results = []
    with open(file_name, 'rt') as f:
        for line in f:
            results.append(line.replace('\n', ''))
    return results

# %%
tweets = file_to_list('tweets.txt')

# %%
print(tweets)
# Out:
# ['Check out the giveaway I found: https://t.co/Qhfm6ZfWkL #SahmReviews #sweeps #java #howyoudripo #coldbrew #coffee #giveaway', 'Adobe Coldfusion Anthology: Clear And Concise Concepts From The Fusion Authority here  https://t.co/XyF1J9kIjs #java #grails @javabot_', "This Stats class is interesting but I fear I'm treading too close to the daRk side.", '#Python', "'Apple' winners: The best, worst and most divisive #fakeheadlinebot #learntocode #makeatwitterbot #javascript", 'RT @jeetrainers: Replacing Legacy #Java EE App Servers With Microservices and Containers https://t.co/FL4Qhq1nDW https://t.co/lbdXBvxTSB', 'RT @lymanefunktion: @gwenstefani and @OfficialSting together on stage at at&amp;t park... what an amazing mixin #java #JavaOne #Oracle #SanFran…', '#Quttera #web #malware scanner daily report 13 drive-by-download attacks https://t.co/SgttHtUdjH #wordpress #joomla #javascript', 'RT @jeetrainers: Docker for #Java Developers https://t.co/NBRfiE4Pj7 https://t.co/pbU6z33NPD', 'RT @GeorgeLudwigBiz: #Scala vs #Java: another view https://t.co/LutsMjpfDq by @Fruzenshtein https://t.co/wJ1IUpAZyf', 'RT nodejstweet: RT npmdaily: boss.validator - The simplest library to validate data or forms. https://t.co/6UCXnMaLuM  #npm #javascript #n…', 'RT nodejstweet: RT npmdaily: weact - React like library for wechat App. https://t.co/n69kx1Snww  #npm #javascript #nodejs', '#Quttera #web #malware scanner daily 229 samples performing suspicious #javascript injection https://t.co/SgttHtUdjH #wordpress #joomla', '#Morgengedicht: Der Nebelparder feilt die Krallen, das wird dem #Python nicht gefallen. https://t.co/jbp7Pe5boK', 'Adobe Acrobat #Javascript for &amp;#039;All Files&amp;#039; option in Save-As Dialogue Box… https://t.co/8FZNoiNELa Hello!!', '3 User experience improving #JavaScript libraries you should know about', 'https://t.co/8ZzEdTKgRA', '---', '#webdesign #UX #webdev #UI', "Idiot's Guides: Raspberry Pi here  https://t.co/A9vfIalf0j #python #programming @pythonbot_", '#JavaScript Curso Front End: Agregando eventos al Widget de Calendario (3/4)... https://t.co/rnUqoNlNAI https://t.co/aNFKrlNnz8', 'RT @chemaalonso: El lado del mal - Análisis de todos los robots.txt del Top 1 Millón del ranking de Alexa #pentesting #Python https://t.co/…', "#Python 関数の引数に * をつけると配列とタプル、 ** をつけると辞書を展開する。func(*[1,2]) は func(1,2) と同意。func(**{'a':1,'b':2}) は func(a=1,b=2)\u3000と同意。", '[05]', 'How Video Games Are Influencing War Propaganda in Angelina Jolie #fakeheadlinebot #learntocode #makeatwitterbot #javascript', 'Intro to Java programming- Learn #Java language basics and start building applications https://t.co/mmlKbl3coC https://t.co/kWoJyqUElQ', 'RT @DebugMe_eu: The Top JavaScript Frameworks for this Year https://t.co/dNSlTxI3DI #frontend #javascript #frameworks #webdev https://t.co/…', 'https://t.co/VMPxLigzxl and Twitter present the most shared #angular2 content from the past 7 days https://t.co/kYVrmC6PIa #javascript', "'macOS Sierra': 7 Questions the Season 2 Finale Must Answer #fakeheadlinebot #learntocode #makeatwitterbot #javascript", 'Graph visualization library in JavaScript #javascript #jquery #data-structures #graph-layout https://t.co/d9LLPAI3TZ', 'RT @polarbear_pc: Leveraging #HTML5 Development #HTML5 #gamedev #coding #programming #phaserjs #JavaScript #HTML #DevOps https://t.co/65sLU…', 'First time programming. Python. Day 1 https://t.co/HLUAopaIDm #python', '#BestJavaBook Effective #Java (2nd Edition) https://t.co/mT57AmQDmQ https://t.co/s7ilG32gYv', '#ruby #code #JavaScript Las #fintechs son flexibles, ágiles y necesitan rapidez en la validación de su actividad https://t.co/rHzmbqgrv1 #…', '“Make your resumé into a slackbot with less than 30 lines of JavaScript” by @jimmywinestock https://t.co/12dK6OsrJJ … #code #javascript', '#JavaScript Curso Front End: Agregando eventos al Widget de Calendario (3/4)... https://t.co/s2wH8tJupA https://t.co/Beb4ZTk3KV', "What's the difference between #Java and #Javascript? https://t.co/T9knDd2B97 https ...
